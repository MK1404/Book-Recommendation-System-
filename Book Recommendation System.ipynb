# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
books=pd.read_csv('Books.csv')

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books=books[['ISBN','Book-Title','Book-Author','Year-Of-Publication','Publisher']]

# %%
books.rename(columns={'Book-Title':'title','Book-Author':'author','Year-Of-Publication':'year','Publisher':'publisher'},inplace=True)

# %%
books.head(2)
# Out:
#          ISBN                title                author  year  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford  2002
# 1  0002005018         Clara Callan  Richard Bruce Wright  2001
#
#                  publisher
# 0  Oxford University Press
# 1    HarperFlamingo Canada

# %%
ratings= pd.read_csv('Ratings.csv')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.rename(columns={'User-ID':'user_id','Book-Rating':'book_rating'},inplace=True)

# %%
ratings.head(2)
# Out:
#    user_id        ISBN  book_rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %%
users=pd.read_csv('Users.csv')
users.head(2)
# Out:
#    User-ID                   Location   Age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
users.rename(columns={'User_ID':'user_id','Location':'location','Age':'age'},inplace=True)

# %%
users.head(2)
# Out:
#    User-ID                   location   age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
ratings.rename(columns={'book_rating':'rating'},inplace=True)

# %%
ratings.head(2)
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5

# %%
print("shape of Books Dataframe :",books.shape)
print("shape of users Dataframe :",users.shape)
print("shape of Ratings Dataframe :",ratings.shape)
# Out:
# shape of Books Dataframe : (271360, 5)
# shape of users Dataframe : (278858, 3)
# shape of Ratings Dataframe : (1149780, 3)

# %%
# find ratings according to users counts
x=ratings['user_id'].value_counts()>200

# %%
y = x[x].index

# %%
y
# Out:
# Int64Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352,
#             110973, 235105,
#             ...
#             260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727,
#             268622, 188951],
#            dtype='int64', length=899)

# %%
ratings=ratings[ratings['user_id'].isin(y)]

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
ratings.head()
# Out:
#       user_id        ISBN  rating
# 1456   277427  002542730X      10
# 1457   277427  0026217457       0
# 1458   277427  003008685X       8
# 1459   277427  0030615321       0
# 1460   277427  0060002050       0

# %%
ratings_with_books=ratings.merge(books, on='ISBN')

# %%
ratings_with_books.shape
# Out:
# (487671, 7)

# %%
number_rating=ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
number_rating.rename(columns={'rating':'Number of Ratings'},inplace=True)

# %%
final_rating=ratings_with_books.merge(number_rating,on='title')

# %%
final_rating.shape
# Out:
# (487671, 8)

# %%
final_rating=final_rating[final_rating['Number of Ratings']>=50]

# %%
final_rating.shape
# Out:
# (61853, 8)

# %%
final_rating.head()
# Out:
#    user_id        ISBN  rating  \
# 0   277427  002542730X      10
# 1     3363  002542730X       0
# 2    11676  002542730X       6
# 3    12538  002542730X      10
# 4    13552  002542730X       0
#
#                                                title             author  year  \
# 0  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 1  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 2  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 3  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
# 4  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner  1994
#
#                    publisher  Number of Ratings
# 0  John Wiley &amp; Sons Inc                 82
# 1  John Wiley &amp; Sons Inc                 82
# 2  John Wiley &amp; Sons Inc                 82
# 3  John Wiley &amp; Sons Inc                 82
# 4  John Wiley &amp; Sons Inc                 82

# %%
final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
final_rating.shape
# Out:
# (59850, 8)

# %%
book_pivot=final_rating.pivot_table(columns='user_id',index='title',values='rating')

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.fillna(0,inplace=True)

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix
book_sparse = csr_matrix(book_pivot)

# %%
type(book_sparse)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors
model=NearestNeighbors(metric = 'cosine',algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
#query_index = np.random.choice(book_pivot.shape[0])
#print(query_index)

# %%
distances,suggestions=model.kneighbors(book_pivot.iloc[46,:].values.reshape(1,-1),n_neighbors=6)

# %%
print(distances)
print(suggestions)
# Out:
# [[0.         0.74809057 0.80978714 0.8139641  0.8156997  0.82276172]]
# [[ 46 569 552 439 650 501]]

# %%
for i in range(len(distances.flatten())):
    if i == 0:
         print(book_pivot.index[suggestions[i]])
# Out:
# Index(['American Gods', 'The Golden Compass (His Dark Materials, Book 1)',
#        'The Eyre Affair: A Novel', 'Seabiscuit: An American Legend',
#        'The Subtle Knife (His Dark Materials, Book 2)',
#        'The Amber Spyglass (His Dark Materials, Book 3)'],
#       dtype='object', name='title')

# %%
def reccomender(book_name):
    book_id=np.where(book_pivot.index == book_name)[0][0]
    distances,suggestions=model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1),n_neighbors=6)
    suggestions = suggestions.flatten().tolist()
    #suggestions = list(book_pivot.index)
    for i in range(len(suggestions)):
        if i == 0:
            return  suggestions
        if not i:
            print(book_pivot.index[suggestions[i]])

# %%
rec = list(rec)
rec
# Out:
# [1, 45, 397, 701, 2, 425]

# %%
rec = reccomender('1st to Die: A Novel')
type(rec)
rec
df[df[]]
final_rating[final_rating.user_id} == rec]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2112/2129672570.py in <module>
# ----> 1 rec = reccomender('1st to Die: A Novel')
#       2 type(rec)
#       3 rec
#       4
#       5 final_rating[final_rating.user_id == rec]
#
# ~\AppData\Local\Temp/ipykernel_2112/602683232.py in reccomender(book_name)
#       6     for i in range(len(suggestions)):
#       7         if i == 0:
# ----> 8             return  final_rating[final_rating.user_id == suggestions]
#       9         if not i:
#      10             print(book_pivot.index[suggestions[i]])
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ...

# %%
import joblib
import pickle

# %%
#pickling means preservation

file="model.pkl"
fileobj = open(file,'wb')
pickle.dump(model,fileobj)

# %%
from flask import Flask,jsonify,request

# %% [raw]
# app = Flask(__name__)
#
# file = 'model.pkl'
# fileobj = open(file,'rb')
# model = pickle.load(fileobj)
#
# @app.route("/")
#
# def

# %%
book_pivot
# Out:
# user_id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...
